# %%
import pandas as pd

employees_df = pd.DataFrame({
    'Name': ["Jonathan", "Will", "Michael", "Liva", "Sia", "Alice"],
    'Age': [20, 22, 29, 20, 20, 21],
    'Weight(KG)': [65, 75, 80, 60, 63, 70],
    'Height(meters)': [1.6, 1.7, 1.85, 1.69, 1.8, 1.75],
    'Salary($)': [3200, 3500, 4000, 2090, 2500, 3600]

})

df = pd.DataFrame({
    "colonne a": [1, 2, 3],
    "colonne b": [6, 7, 8],
    "colonne c": [0, 0, 1]
})

print(df, "\n")
print(employees_df, "\n")
# Out:
#    colonne a  colonne b  colonne c
# 0          1          6          0
# 1          2          7          0
# 2          3          8          1
#
#        Name  Age  Weight(KG)  Height(meters)  Salary($)
# 0  Jonathan   20          65            1.60       3200
# 1      Will   22          75            1.70       3500
# 2   Michael   29          80            1.85       4000
# 3      Liva   20          60            1.69       2090
# 4       Sia   20          63            1.80       2500
# 5     Alice   21          70            1.75       3600

# %%
import numpy as np
import pandas as pd
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s, "\n")
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Afficher les 15 premières lignes du tableau covid_sexe.csv. (df.head?)

# %%
import pandas as pd

df = pd.read_csv('reduced_covid_sexe.csv')

df.head(15)
# Out:
#     Unnamed: 0     hosp   hosp.1  hosp.2     rea   rea.1   rea.2     rad  \
# 0         sexe      0.0      1.0     2.0     0.0     1.0     2.0     0.0
# 1         jour      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 2   2020-03-18   2972.0   1685.0  1248.0   771.0   525.0   239.0   816.0
# 3   2020-03-19   4073.0   2256.0  1632.0  1002.0   689.0   284.0  1180.0
# 4   2020-03-20   5226.0   2912.0  2134.0  1297.0   905.0   362.0  1587.0
# 5   2020-03-21   5900.0   3298.0  2401.0  1453.0  1018.0   401.0  1811.0
# 6   2020-03-22   6954.0   3906.0  2815.0  1674.0  1176.0   461.0  2117.0
# 7   2020-03-23   8673.0   4882.0  3532.0  2080.0  1465.0   569.0  2567.0
# 8   2020-03-24  10163.0   5843.0  4149.0  2503.0  1773.0   694.0  3281.0
# 9   2020-03-25  12072.0   7064.0  4856.0  2935.0  2127.0   785.0  4085.0
# 10  2020-03-26  13879.0   8152.0  5570.0  3351.0  2437.0   888.0  4947.0
# 11  2020-03-27  15701.0   9288.0  6248.0  3758.0  2735.0   991.0  5698.0
# ...

# %% [markdown]
# Afficher les 15 dernières lignes du tableau covid_sexe.csv. (df.tail?

# %%
import pandas as pd

df = pd.read_csv('reduced_covid_sexe.csv')

df.tail(15)
# Out:
#       Unnamed: 0     hosp  hosp.1  hosp.2    rea  rea.1  rea.2       rad  \
# 1096  2023-03-17  13279.0  5982.0  7058.0  755.0  461.0  285.0  858444.0
# 1097  2023-03-18  13205.0  5973.0  6995.0  752.0  462.0  282.0  858672.0
# 1098  2023-03-19  13211.0  5979.0  6995.0  754.0  463.0  283.0  858680.0
# 1099  2023-03-20  13358.0  6052.0  7068.0  760.0  469.0  282.0  859128.0
# 1100  2023-03-21  13434.0  6083.0  7109.0  761.0  463.0  289.0  859586.0
# 1101  2023-03-22  13418.0  6088.0  7090.0  761.0  469.0  283.0  860128.0
# 1102  2023-03-23  13025.0  5912.0  6870.0  739.0  456.0  273.0  860867.0
# 1103  2023-03-24  13103.0  5937.0  6917.0  751.0  466.0  275.0  861310.0
# 1104  2023-03-25  13038.0  5902.0  6890.0  744.0  463.0  271.0  861538.0
# 1105  2023-03-26  13036.0  5903.0  6889.0  746.0  466.0  270.0  861565.0
# 1106  2023-03-27  13113.0  5950.0  6923.0  728.0  457.0  263.0  861972.0
# 1107  2023-03-28  13178.0  6000.0  6943.0  720.0  452.0  261.0  862458.0
# ...

# %%
import pandas as pd

df = pd.read_csv('metadata_covid_sexe.csv', sep = ";", encoding='latin')
df
# Out:
#     Colonne          Type                                      Description_FR  \
# 0       dep        integer                                       DÃ©partement
# 1      sexe        integer                                              Sexe
# 2      jour  string($date)                              Date de notification
# 3      hosp        integer     Nombre de personnes actuellement hospitalisées
# 4       rea        integer  Nombre de personnes actuellement en services d...
# 5       rad        integer   Nombre cumulé de personnes retournées à domicile
# 6        dc        integer    Nombre cumulé de personnes décédées à l'hôpital
# 7  ssr_usld        integer  Nombre de personnes actuellement en services d...
# 8  hospconv        integer  Nombre de personnes actuellement en services d...
# 9   autres         integer  Nombre de personnes actuellement en autres typ...
#
#                                       Description_EN     Exemple
# ...

# %% [markdown]
# EXO :: Quelle est la période temporelle sur laquelle s'étendent les données ?
# Sur combien de jours s'étale les données ? années ?

# %%
import pandas as pd

df = pd.read_csv('reduced_covid_sexe.csv')
dates = df[2:][	'Unnamed: 0']
dates = dates.apply(pd.to_datetime)



date_range =(dates.max() - dates.min())
n_jour = date_range.days +1

print("Nombre de jours entre le premier et le dernier cas: ", n_jour)
print("Premier cas: ", dates.min())
print("Dernier cas: ", dates.max())
# Out:
# Nombre de jours entre le premier et le dernier cas:  1109
# Premier cas:  2020-03-18 00:00:00
# Dernier cas:  2023-03-31 00:00:00

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Lire le fichier CSV
df = pd.read_csv('reduced_covid_sexe.csv')
plt.figure(figsize=(8, 6))
corr_df = df.corr(method='pearson')
sns.heatmap(df.corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm', mask=upp_mat)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_17628\101358704.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = df.corr(method='pearson')
# C:\Users\charl\AppData\Local\Temp\ipykernel_17628\101358704.py:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm', mask=upp_mat)
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
df = pd.read_csv('reduced_covid_sexe.csv')
FemeH = df[2:][	'hosp.1']
FemeR = df[2:][	'rea.1']
kemeH = df[2:][	'hosp.2']
kemeR = df[2:][	'rea.2']

#Tracer l'evolution sur un même graphique des données ci dessus
plt.plot(FemeH, label = "Femme hospitalisée")
plt.plot(FemeR, label = "Femme en réanimation")
plt.plot(kemeH, label = "Homme hospitalisé")
plt.plot(kemeR, label = "Homme en réanimation")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt



fig0, ax0 = plt.subplots()
ax1 = ax0.twinx()

#Tracer sut le même graphique le nombre de décès cumulés pour les hommes et pour les femmes sur une échelle verticale différente/sépare 
df = pd.read_csv('reduced_covid_sexe.csv')
FemeD = df[2:][	'dc.1']
kemeD = df[2:][	'dc.2']
plt.plot(FemeD, label = "Femme décédée")
plt.plot(kemeD, label = "Homme décédé")
plt.legend()
plt.show()

# %% [markdown]
# Quelle est la probabilité pour un Français (vs) une Française de mourir du Covid au début de la période disponible ? à la fin de la période disponible ?

# %%
#Quelle est la probabilité pour un Français (vs) une Française de mourir du Covid au début de la période disponible ? à la fin de la période disponible ?

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('reduced_covid_sexe.csv')
FemeDbegin = df[2:3]['dc.1']
FemeDend = df.tail(1)['dc.1']
kemeDbegin = df[2:3]['dc.2']
kemeDend = df.tail(1)['dc.2']

total_deaths_begin = FemeDbegin + kemeDbegin
probability_female_begin = FemeDbegin / total_deaths_begin
probability_male_begin = kemeDbegin / total_deaths_begin

print("Probabilité pour une Française de mourir du Covid au début de la période donnée :", probability_female_begin)
print("Probabilité pour un Français de mourir du Covid au début de la période donnée :", probability_male_begin)

total_deaths_end = FemeDend + kemeDend
probability_female_end = FemeDend / total_deaths_end
probability_male_end = kemeDend / total_deaths_end

print("Probabilité pour une Française de mourir du Covid aa la fin de la période donnée :", probability_female_begin)
print("Probabilité pour un Français de mourir du Covid a la fin de la période donnée :", probability_male_begin)
# Out:
# Probabilité pour une Française de mourir du Covid au début de la période donnée : 2    0.557604
# dtype: float64
# Probabilité pour un Français de mourir du Covid au début de la période donnée : 2    0.442396
# dtype: float64
# Probabilité pour une Française de mourir du Covid aa la fin de la période donnée : 2    0.557604
# dtype: float64
# Probabilité pour un Français de mourir du Covid a la fin de la période donnée : 2    0.442396
# dtype: float64
